# %%
! pip install mysql-connector-python
import mysql.connector
import pandas as pd
import json
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\m_4ris_5t\appdata\local\programs\python\python36-32\lib\site-packages (8.0.29)
# Requirement already satisfied: protobuf>=3.0.0 in c:\users\m_4ris_5t\appdata\local\programs\python\python36-32\lib\site-packages (from mysql-connector-python) (3.19.4)

# %%
con = open('ref_con/db-prima', 'r').read().splitlines()
how = input('how to connect(local/public):')

mydb = mysql.connector.connect(
  host=con[0] if how == 'public' else con[1],
  user=con[2],
  password=con[3],
  database=con[4],
  autocommit=True
)

mycursor = mydb.cursor(dictionary=True)

# %%
import re
from functools import partial

def exec_q_row(qT):
  mycursor.execute(qT)
  myresult = mycursor.fetchall()
  jD = []
  for x in myresult:
    jD.append(x['notes_json'])
  return jD

def get_text(list_json,key = ['notesmedis','Tx']):
  arN = []
  for x in notes_medis:
      a = json.loads(x)
      for y in a[key[0]]:
        arN.append(y[key[1]])
          # if re.search(r'^\[', y[key[1]]):
            # t = y[key[1]]
            # t = t[t.find("[")+1:t.find("]")]
            # arN.append(t)
  return arN

def get_text_v(list_json):
 lst = get_text(list_json)
 rtr = []
 for x in lst:
   if re.search(r'^\[', x):
     t = re.search('\[([^]]+)', x).group(1)
     if(t not in rtr and t.isnumeric() == False): rtr.append(t)
 return rtr

# %%
notes_medis = exec_q_row("select notes_json from primaprod.mr_notes where notes_json like '%notesmedis%'")

DF_notes_medis = pd.DataFrame(get_text_v(notes_medis))
DF_notes_medis
# Out:
#                                                     0
# 0                                        CATATAN_TBAK
# 1                                                 KTP
# 2                                 gbr:hasil-audiogram
# 3                                    INFORMED CONSENT
# 4                                MASALAH_TINDAKAN_ICU
# 5                                      EDUKASI PASIEN
# 6                                     GENERAL CONSENT
# 7                                           LAIN-LAIN
# 8                                          KARTU BPJS
# 9                                                  KK
# 10                               HASIL SWAB DARI LUAR
# 11                       SURAT PERNYATAAN BEBAS BIAYA
# 12                                      SURAT RUJUKAN
# 13                                                  p
# 14                                 KARTU JAMINAN LAIN
# 15                              SURAT ISOLASI MANDIRI
# 16                                       CATATAN-TBAK
# 17  CATATAN_TBAK\nkonsul KOMDIK dr. Thariq SP. An ...
# 18  MASALAH_TINDAKAN_I\nadvice dr iqra, spOG jam 9...
# 19  MASALAH_TINDAKAN_\nadvice dr navy, spANKIC JAM...
# 20                                             TEBAK
# 21                               Masalah Tindakan ICU
# 22                               masalah Tindakan ICU
# 23  MASALAH_TINDAKAN_ICCU\nTINDAKAN : JAM.12.30 Dr...
# 24  CATATAN_TBAK} : DPJP dr Yuyun, SpOG(K): Cek La...
# 25  CATATAN_TBAK:  lapor hasil lab troponin i yg k...
# 26                                       CATATAB_TBAK
# 27  CAinstruksi dr. iqbal : sefotaxim 3x1hr\nketor...
# 28  CATATinstruksi dr. iqbal : sefotaxim 3x1hr\nke...
# 29  CATATAN_TBAKKonsul dr. Prasenohadi, Sp.P(K) un...
# 30  MASALAH_:\nMASALAH :  jam 08.15 hemodinamik st...
# 31                                         CATATAN_AK
# 32          CATATAN_TBAKInstruksi dr Yasmina SpJP :\n
# 33                                      CATATAN_TBA K
# 34  CATATAN_TBAAdvise dr aldila : \nhrus segera di...
# 35  CATAInstruksi pasca intub dari dr. aldila, spa...
# 36                                       TBAK_CATATAN
