# %%
import pandas as pd
import numpy as np

# %%
DS = pd.read_excel (r'Documents\uji-simak-2101.xls', sheet_name=input("sheet name simak:"), header=None)
# Out:
# sheet name simak:rinci pr 2112 I

# %%
DP = pd.read_excel (r'Documents\uji-simak-2101.xls', sheet_name=input("sheet name prima:"), header=None)
# Out:
# sheet name prima:rinci pr 2112

# %%
def sumR(D,r = 1):
    return D[[r]].sum()

def komparasiDenganDesc(D1,D2,r=0):
    return pd.merge(D1,D2,on=r,how='outer',indicator=True)

# %%
DSG = DS.groupby(by=0).sum()
DSG
# Out:
#                                        1
# 0
# |101040100100000000000000000014|   102.0
# |10104010010000000000000000002c|     0.0
# |10104010010000000000000000002z|  2324.0
# |1010401001000000000000000002FO|     0.0
# |10104010010000000000000000031y|     0.0
# |1010401001000000000000000003AZ|     8.0
# |101040100100000000000000002231|  4380.0
# |101040100100000000000000002254|    39.0
# |101040100100000000000000002256|    23.0
# |101040100100000000000000002330|   244.0
# |101040100100000000000000002584|     0.0
# |101040100100000000000000003001|     0.0
# |101040100100000000000000003011|     1.0
# |101040100100000000000000003080|     0.0
# |101040100100000000000000003099|     0.0
# |101040100100000000000000003265|  3002.0
# |101040100100000000000000003333|    67.0
# |101040100100000000000000003345|     3.0
# |101040100100000000000000009987|    41.0
# |10104010010000000000000000L106|     0.0
# |101040100100000000000000011556|    69.0
# |101040100100000000000000013541|     0.0
# |101040100100000000000000022254|    54.0
# |101040100100000000000000022358|  6613.0
# |101040100100000000000000022510|   275.0
# |101040100100000000000000022531|     0.0
# |101040100100000000000000022580|     0.0
# |101040100100000000000000023201|     3.0
# |101040100100000000000000023210|     0.0
# |101040100100000000000000025410|     0.0
# ...                                  ...
# |1010401999000000000002.060.003|     2.0
# |1010401999000000000002.060.005|     0.0
# |1010401999000000000002.060.023|     0.0
# |1010401999000000000002.060.031|     1.0
# |1010401999000000000002.060.046|     0.0
# |1010401999000000000003.020.013|    39.2
# |1010401999000000000003.040.004|     0.0
# |1010401999000000000003.040.005|     0.0
# |1010401999000000000003.040.014|     0.0
# |1010401999000000000003.040.016|     0.0
# |1010401999000000000003.040.046|     0.0
# |1010401999000000000003.040.047|     2.0
# |1010401999000000000003.040.051|     0.0
# |1010401999000000000003.040.052|     1.0
# |1010401999000000000003.040.053|     0.0
# |1010401999000000000003.040.058|     1.0
# |1010401999000000000003.040.147|     0.0
# |1010401999000000000003.050.161|     0.0
# |101040199900000000000300.088.6|     0.0
# |101040199900000000000301.008.5|     0.0
# |101040199900000000000304.138.1|     1.0
# |1010401999000000000009010148.6|   188.0
# |10104019990000000003.030.005.5|     0.0
# |10104019990000000003.030.032.8|     0.0
# |10104019990000000003.040.046.1|     3.0
# |10104019990000000003.040.073.2|     0.0
# |10104019990000000003.040.127.2|     0.0
# |10104019990000000003.040.157.1|     1.0
# |10104019990000000003.040.157.2|     0.0
# |1010401999000000002.20072017.1|     0.0
#
# [4853 rows x 1 columns]

# %%
DResCompare = komparasiDenganDesc(DSG,DP)
DResCompare.loc[:,'selisih'] = DResCompare['1_y'].fillna(0) - DResCompare['1_x'].fillna(0)
DResCompare.loc[:,'kodeTrans'] = np.where(DResCompare['selisih'] < 0, '|P02|', '|P01|')
DResCompare.loc[:,'abs_selisih'] = DResCompare['selisih'].abs()
DResCompare.loc[:,'nama item'] = "|" + DResCompare[4] + "|"
DResCompare.loc[:,'satuan'] = "|" + DResCompare[5] + "|"
DResCompare.loc[:,'hna'] = DResCompare[6]

idTrans = '|024040100415448241KD2021Y0001'
idx = 0
#DResCompare.loc[:,'id_trans'] = idTrans + (np.where(DResCompare['selisih'] < 0,'K','M')) + '|'

DResCompare['id_trans'] = DResCompare.iloc[:,1:].astype(str).\
apply(lambda x: idTrans ,axis=1)
DResCompare['mk_trans'] = DResCompare.iloc[:,1:].astype(str).\
apply(lambda x: ('K' if x['kodeTrans'] == '|P02|' else 'M') + '|' ,axis=1)
DResCompare['tgl_trans'] = DResCompare.iloc[:,1:].astype(str).\
apply(lambda x: ('31-12-2021 23:00:00' if x['kodeTrans'] == '|P02|' else '01-12-2021 23:00:00'),axis=1)

DResCompare.rename(columns={"key_0": "kode gabung", "1_x": "qty persediaan", "1_y": "qty prima"\
                           }, inplace = True)

DResCompare[['kode gabung','qty persediaan','qty prima',2,3,'nama item','satuan','hna',\
             '_merge','selisih','kodeTrans','abs_selisih','id_trans','mk_trans','tgl_trans']]\
[((DResCompare['_merge'] != 'both') | ((DResCompare['_merge'] == 'both')\
            & (DResCompare['qty persediaan'] != DResCompare['qty prima']))) & (DResCompare['selisih'] != 0)]\
    .to_excel (r'Documents\hasil-uji-simak-'+input('periode :')+'.xls', index = False, header=True)
# Out:
# periode :2112 II
